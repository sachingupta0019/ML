# %%
import numpy as np
import pandas as pd

car = pd.read_csv("quikr_car.csv")
car_backup = car.copy()
car_backup.shape
# Out:
# (892, 6)

# %% [markdown]
# 1. Year has many non-year values
# 2. year obj -> int
# 3. price has string values
# 4. prict obj -> int
# 5. kms_value has NaN
# 6. kms_values has kms string
# 7. kms_value obj -> int
# 8. fuel type has NaN
# 9. keep 3 words of name

# %% [markdown]
# 1. Year

# %%
# car_backup['year'] = car_backup['year'].fillna(car_backup['year'].median())
# car_backup['year'] = car_backup["year"].astype(int)
# car_backup['year'] = pd.to_numeric(car_backup['year'], errors='coerce')

# %%
car_backup = car_backup[car_backup['year'].str.isnumeric()]
car_backup['year'] = car_backup['year'].astype(int)

# %% [markdown]
# 2. Price

# %%
car_backup = car_backup[car_backup['Price'] != 'Ask For Price']
car_backup['Price'] = car_backup['Price'].str.replace(',','').astype(int)

# %% [markdown]
# 3. Kms

# %%
car_backup['kms_driven'] = car_backup['kms_driven'].str.split(",").str.get(0)

# %%
car_backup = car_backup[car_backup['kms_driven'].fillna(' ').str.isnumeric()]
car_backup['kms_driven'] = car_backup['kms_driven'].astype(int)

# %%
car_backup = car_backup[~car_backup['fuel_type'].isna()]

# %% [markdown]
# Name

# %%
car_backup['name'] = car_backup['name'].str.split(' ').str.slice(0,3).str.join(' ')

# %%
car_backup.shape
# Out:
# (799, 6)

# %% [markdown]
# Converting Year string to int

# %%
car_backup[car_backup['Price']<6e6]
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000          45    Petrol
# 3         Hyundai Grand i10   Hyundai  2014  325000          28    Petrol
# 4    Ford EcoSport Titanium      Ford  2014  575000          36    Diesel
# 6                 Ford Figo      Ford  2012  175000          41    Diesel
# 7               Hyundai Eon   Hyundai  2013  190000          25    Petrol
# ..                      ...       ...   ...     ...         ...       ...
# 883      Maruti Suzuki Ritz    Maruti  2011  270000          50    Petrol
# 885          Tata Indica V2      Tata  2009  110000          30    Diesel
# 886    Toyota Corolla Altis    Toyota  2009  300000           1    Petrol
# 888            Tata Zest XM      Tata  2018  260000          27    Diesel
# 889      Mahindra Quanto C8  Mahindra  2013  390000          40    Diesel
#
# [798 rows x 6 columns]

# %%
car_backup.to_csv('cleaned_car.csv')

# %% [markdown]
# # Model

# %%
x = car_backup.drop(columns='Price')
y = car_backup['Price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.compose import make_column_transformer
from sklearn.pipeline import  make_pipeline


X_train, X_test, y_train ,y_test = train_test_split(x, y, test_size=0.2)

# %%
ohe = OneHotEncoder()
ohe.fit(x[['name','company', 'fuel_type']])
# Out:
# OneHotEncoder()

# %%
ohe.categories_
# Out:
# [array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#         'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#         'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#         'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat Diesel',
#         'Chevrolet Beat LS', 'Chevrolet Beat LT', 'Chevrolet Beat PS',
#         'Chevrolet Cruze LTZ', 'Chevrolet Enjoy', 'Chevrolet Enjoy 1.4',
#         'Chevrolet Sail 1.2', 'Chevrolet Sail UVA', 'Chevrolet Spark',
#         'Chevrolet Spark 1.0', 'Chevrolet Spark LS', 'Chevrolet Spark LT',
#         'Chevrolet Tavera LS', 'Chevrolet Tavera Neo', 'Datsun GO T',
#         'Datsun Go Plus', 'Datsun Redi GO', 'Fiat Linea Emotion',
#         'Fiat Petra ELX', 'Fiat Punto Emotion', 'Force Motors Force',
#         'Force Motors One', 'Ford EcoSport', 'Ford EcoSport Ambiente',
#         'Ford EcoSport Titanium', 'Ford EcoSport Trend',
# ...

# %%
col_trans = make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']), remainder='passthrough')

# %%
lr = LinearRegression()

# %%
pipe = make_pipeline(col_trans, lr)

# %%
pipe.fit(X_train, y_train)
# Out:
# c:\Users\Sachi\Desktop\ML\Linear_Regression\.car_price_env\Lib\site-packages\sklearn\compose\_column_transformer.py:1667: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
# ...

# %%
y_predit = pipe.predict(X_test)

# %%
r2_score(y_test, y_predit)
# Out:
# 0.2240814218654278

# %%
scores = []
for i in range(100):
    X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=i)
    lr = LinearRegression()
    pipe = make_pipeline(col_trans, lr)
    pipe.fit(X_train, y_train)
    y_predict = pipe.predict(X_test)
    scores.append(r2_score(y_test,y_predict))

# %%
scores[np.argmax(scores)]
# Out:
# 0.8833165209147034

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=np.argmax(scores))
lr = LinearRegression()
pipe = make_pipeline(col_trans, lr)
pipe.fit(X_train, y_train)
y_predict = pipe.predict(X_test)
r2_score(y_test,y_predict)
# Out:
# 0.8833165209147034

# %%
import pickle

# %%
pickle.dump(pipe, open("LinearRegressionModel.pkl", "wb"))

# %%
pipe.predict(pd.DataFrame([['Maruti Suzuki Swift', 'Maruti', 2019, 100, 'Petrol']], columns=['name','company','year','kms_driven','fuel_type']))
# Out:
# array([432930.93404941])
